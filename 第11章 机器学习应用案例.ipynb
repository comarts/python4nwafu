# %% [markdown]
# # 第1章 程序设计基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第2章 Python 语言基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第3章 基本控制结构
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第4章 复合数据类型
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第5章 编程思维与方法
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第6章 自定义函数
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第7章 文件操作
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第8章 面向对象编程基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第9章 软件开发基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第10章 编程环境配置
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第11章 机器学习应用案例

# %% [markdown]
# ## 机器学习简介与实践基础
#
# ### 机器学习介绍
#
# ### 机器学习的三大范式
#
# ### 机器学习的第三方库
#
# ### ✍️伴读札记

# %% [markdown]
# ## 基于KNN 方法的葡萄酒分类
#
# ### 问题描述
#
# ### KNN 算法简介
#
# ### 代码实现
#
# ### ✍️伴读札记

# %% [markdown]
# ## 基于线性回归算法的自行车共享需求预测
#
# ### 问题描述
#
# ### 线性回归算法简介
#
# ### 代码实现
#
#
# ### ✍️伴读札记

# %% [markdown]
# ## 基于 K-means 算法的鸢尾花聚类案例
#
# ### 问题描述
#
# ### K-means 算法简介
#
# ### 模块划分及代码实现
#
# ### ✍️伴读札记
