# %% [markdown]
# # 第1章 程序设计基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第2章 Python 语言基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第3章 基本控制结构
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第4章 复合数据类型
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第5章 编程思维与方法
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第6章 自定义函数
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第7章 文件操作
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第8章 面向对象编程基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第9章 软件开发基础

# %% [markdown]
# ## 手机通信录管理软件开发案例
#
# ### 通信录设计需求
#
# ### 通信录管理软件设计
#
# ### 通信录代码实现
#
# ### 通信录功能测试
#
# ### 通信录管理软件的部署维护
#
# ### ✍️伴读札记

# %% [markdown]
# ## 软件开发的一般流程
#
# ### 需求分析
#
# ### 软件设计
#
# ### 编码实现
#
# ### 测试调试
#
# ### 部署维护
#
#
# ### ✍️伴读札记

# %% [markdown]
# ## 软件开发概述
#
# ### 软件开发的基本概念
#
# ### 软件开发的基本原则
#
# ### 常用的软件开发模型
#
# ### 软件开发的常用工具与资源
#
# ### ✍️伴读札记
