# %% [markdown]
# # 第1章 程序设计基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第2章 Python 语言基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第3章 基本控制结构
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第4章 复合数据类型
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第5章 编程思维与方法
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第6章 自定义函数
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第7章 文件操作
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第8章 面向对象编程基础

# %% [markdown]
# ## 面向对象基本认知
#
# ### 过程式编程与面向对象编程
#
# ### 类与对象的概念
#
# ### 面向对象程序设计思想
#
# ### ✍️伴读札记

# %% [markdown]
# ## 类的定义与对象的创建
#
# ### 类的定义与构造方法
#
# ### 对象的创建与属性空间
#
# ### 实例方法的定义与调用
#
# ### ✍️伴读札记

# %% [markdown]
# ## 面向对象的集成机制
#
# ### 继承的基本概念和作用
#
# ### 子类的定义与构造方法的集成
#
# ### 子类方法的重写
#
# ### ✍️伴读札记

# %% [markdown]
# ## 面向对象应用案例
#
# ### ✍️伴读札记
